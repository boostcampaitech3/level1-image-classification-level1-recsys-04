# %%
# !python /opt/ml/level1-image-classification-level1-recsys-04/model/FaceAndCutmix/train.py \
    --epochs 10 \
    --dataset 'CutMixDataset' \
    --augmentation 'CustomAugmentation' \
    --batch_size 32 \
    --valid_batch_size 32 \
    --model 'EfficientNet_MultiLabel' \
    --lr '1e-4' \
    --lr_decay_step '10' \
    --name 'Face_Cutmix_label_smoothing' \
    --model_dir './model/'
# Out:
# Namespace(augmentation='CustomAugmentation', batch_size=32, criterion='cross_entropy', data_dir='/opt/ml/input/data/train/images', dataset='CutMixDataset', epochs=10, log_interval=20, lr=0.0001, lr_decay_step=10, model='EfficientNet_MultiLabel', model_dir='./model/', name='Face_Cutmix_label_smoothing', optimizer='Adam', resize=[380, 380], seed=42, val_ratio=0.2, valid_batch_size=32)
# Loaded pretrained weights for efficientnet-b4
# Epoch[0/10](20/410) || training loss 2.777 || training accuracy 22.66% || lr 0.0001
# Epoch[0/10](40/410) || training loss 2.442 || training accuracy 44.69% || lr 0.0001
# Epoch[0/10](60/410) || training loss 1.88 || training accuracy 63.28% || lr 0.0001
# Epoch[0/10](80/410) || training loss 1.339 || training accuracy 73.59% || lr 0.0001
# Epoch[0/10](100/410) || training loss 0.9929 || training accuracy 79.53% || lr 0.0001
# Epoch[0/10](120/410) || training loss 0.7691 || training accuracy 79.06% || lr 0.0001
# Epoch[0/10](140/410) || training loss 0.6065 || training accuracy 85.16% || lr 0.0001
# Epoch[0/10](160/410) || training loss 0.4907 || training accuracy 87.66% || lr 0.0001
# Epoch[0/10](180/410) || training loss 0.4394 || training accuracy 87.66% || lr 0.0001
# Epoch[0/10](200/410) || training loss 0.4141 || training accuracy 87.19% || lr 0.0001
# Epoch[0/10](220/410) || training loss 0.3521 || training accuracy 90.31% || lr 0.0001
# Epoch[0/10](240/410) || training loss 0.2927 || training accuracy 92.19% || lr 0.0001
# Epoch[0/10](260/410) || training loss 0.2895 || training accuracy 91.72% || lr 0.0001
# Epoch[0/10](280/410) || training loss 0.307 || training accuracy 91.09% || lr 0.0001
# Epoch[0/10](300/410) || training loss 0.2335 || training accuracy 92.97% || lr 0.0001
# Epoch[0/10](320/410) || training loss 0.2422 || training accuracy 93.44% || lr 0.0001
# Epoch[0/10](340/410) || training loss 0.2266 || training accuracy 93.28% || lr 0.0001
# Epoch[0/10](360/410) || training loss 0.2203 || training accuracy 93.28% || lr 0.0001
# Epoch[0/10](380/410) || training loss 0.1864 || training accuracy 94.38% || lr 0.0001
# Epoch[0/10](400/410) || training loss 0.2202 || training accuracy 92.97% || lr 0.0001
# Calculating validation results...
# New best model for val accuracy : 86.44%! saving the best model..
# [Val] acc : 86.44%, loss: 0.38 || best acc : 86.44%, best loss: 0.38
# Accuracy By Each Label
# Age : 0, Accuracy By Age : 0.94%
# Age : 1, Accuracy By Age : 0.85%
# Age : 2, Accuracy By Age : 0.83%
# Gender : 0, Accuracy By Gender : 0.86%
# Gender : 1, Accuracy By Gender : 0.88%
# Mask : 0, Accuracy By Mask : 0.87%
# Mask : 1, Accuracy By Mask : 0.87%
# Mask : 2, Accuracy By Mask : 0.88%
#
# Epoch[1/10](20/410) || training loss 0.1433 || training accuracy 96.25% || lr 9.804226065180615e-05
# Epoch[1/10](40/410) || training loss 0.1358 || training accuracy 95.94% || lr 9.804226065180615e-05
# Epoch[1/10](60/410) || training loss 0.1563 || training accuracy 95.31% || lr 9.804226065180615e-05
# Epoch[1/10](80/410) || training loss 0.171 || training accuracy 94.06% || lr 9.804226065180615e-05
# Epoch[1/10](100/410) || training loss 0.1295 || training accuracy 96.72% || lr 9.804226065180615e-05
# Epoch[1/10](120/410) || training loss 0.1333 || training accuracy 96.72% || lr 9.804226065180615e-05
# Epoch[1/10](140/410) || training loss 0.136 || training accuracy 95.94% || lr 9.804226065180615e-05
# Epoch[1/10](160/410) || training loss 0.1182 || training accuracy 96.56% || lr 9.804226065180615e-05
# Epoch[1/10](180/410) || training loss 0.1299 || training accuracy 96.56% || lr 9.804226065180615e-05
# Epoch[1/10](200/410) || training loss 0.09684 || training accuracy 97.34% || lr 9.804226065180615e-05
# Epoch[1/10](220/410) || training loss 0.1179 || training accuracy 96.41% || lr 9.804226065180615e-05
# Epoch[1/10](240/410) || training loss 0.1025 || training accuracy 97.03% || lr 9.804226065180615e-05
# Epoch[1/10](260/410) || training loss 0.1471 || training accuracy 96.09% || lr 9.804226065180615e-05
# Epoch[1/10](280/410) || training loss 0.1142 || training accuracy 96.56% || lr 9.804226065180615e-05
# Epoch[1/10](300/410) || training loss 0.1178 || training accuracy 97.34% || lr 9.804226065180615e-05
# Epoch[1/10](320/410) || training loss 0.09351 || training accuracy 97.81% || lr 9.804226065180615e-05
# Epoch[1/10](340/410) || training loss 0.05266 || training accuracy 98.91% || lr 9.804226065180615e-05
# Epoch[1/10](360/410) || training loss 0.06368 || training accuracy 98.44% || lr 9.804226065180615e-05
# Epoch[1/10](380/410) || training loss 0.06602 || training accuracy 98.28% || lr 9.804226065180615e-05
# Epoch[1/10](400/410) || training loss 0.06924 || training accuracy 98.44% || lr 9.804226065180615e-05
# Calculating validation results...
# New best model for val accuracy : 90.74%! saving the best model..
# [Val] acc : 90.74%, loss: 0.27 || best acc : 90.74%, best loss: 0.27
# Accuracy By Each Label
# Age : 0, Accuracy By Age : 0.95%
# Age : 1, Accuracy By Age : 0.93%
# Age : 2, Accuracy By Age : 0.87%
# Gender : 0, Accuracy By Gender : 0.91%
# Gender : 1, Accuracy By Gender : 0.92%
# Mask : 0, Accuracy By Mask :  0.9%
# Mask : 1, Accuracy By Mask : 0.93%
# Mask : 2, Accuracy By Mask : 0.91%
#
# Epoch[2/10](20/410) || training loss 0.07413 || training accuracy 98.44% || lr 9.23606797749979e-05
# Epoch[2/10](40/410) || training loss 0.04497 || training accuracy 99.06% || lr 9.23606797749979e-05
# Epoch[2/10](60/410) || training loss 0.06427 || training accuracy 98.12% || lr 9.23606797749979e-05
# Epoch[2/10](80/410) || training loss 0.07026 || training accuracy 98.44% || lr 9.23606797749979e-05
# Epoch[2/10](100/410) || training loss 0.0556 || training accuracy 98.59% || lr 9.23606797749979e-05
# Epoch[2/10](120/410) || training loss 0.05888 || training accuracy 98.28% || lr 9.23606797749979e-05
# Epoch[2/10](140/410) || training loss 0.06033 || training accuracy 98.44% || lr 9.23606797749979e-05
# Epoch[2/10](160/410) || training loss 0.04945 || training accuracy 98.75% || lr 9.23606797749979e-05
# Epoch[2/10](180/410) || training loss 0.08734 || training accuracy 97.50% || lr 9.23606797749979e-05
# Epoch[2/10](200/410) || training loss 0.06131 || training accuracy 98.12% || lr 9.23606797749979e-05
# Epoch[2/10](220/410) || training loss 0.0657 || training accuracy 98.12% || lr 9.23606797749979e-05
# Epoch[2/10](240/410) || training loss 0.05538 || training accuracy 98.12% || lr 9.23606797749979e-05
# Epoch[2/10](260/410) || training loss 0.06725 || training accuracy 98.59% || lr 9.23606797749979e-05
# Epoch[2/10](280/410) || training loss 0.04914 || training accuracy 99.06% || lr 9.23606797749979e-05
# Epoch[2/10](300/410) || training loss 0.04701 || training accuracy 98.59% || lr 9.23606797749979e-05
# Epoch[2/10](320/410) || training loss 0.05868 || training accuracy 98.28% || lr 9.23606797749979e-05
# Epoch[2/10](340/410) || training loss 0.05319 || training accuracy 98.59% || lr 9.23606797749979e-05
# Epoch[2/10](360/410) || training loss 0.04866 || training accuracy 98.75% || lr 9.23606797749979e-05
# Epoch[2/10](380/410) || training loss 0.04063 || training accuracy 98.75% || lr 9.23606797749979e-05
# Epoch[2/10](400/410) || training loss 0.04881 || training accuracy 99.06% || lr 9.23606797749979e-05
# Calculating validation results...
# New best model for val accuracy : 91.26%! saving the best model..
# [Val] acc : 91.26%, loss:  0.3 || best acc : 91.26%, best loss: 0.27
# Accuracy By Each Label
# Age : 0, Accuracy By Age : 0.99%
# Age : 1, Accuracy By Age : 0.95%
# Age : 2, Accuracy By Age : 0.82%
# Gender : 0, Accuracy By Gender : 0.93%
# Gender : 1, Accuracy By Gender : 0.91%
# Mask : 0, Accuracy By Mask : 0.93%
# Mask : 1, Accuracy By Mask : 0.94%
# Mask : 2, Accuracy By Mask : 0.89%
#
# Epoch[3/10](20/410) || training loss 0.05448 || training accuracy 98.59% || lr 8.351141009169893e-05
# Epoch[3/10](40/410) || training loss 0.06105 || training accuracy 98.12% || lr 8.351141009169893e-05
# Epoch[3/10](60/410) || training loss 0.04267 || training accuracy 99.06% || lr 8.351141009169893e-05
# Epoch[3/10](80/410) || training loss 0.06395 || training accuracy 98.28% || lr 8.351141009169893e-05
# Epoch[3/10](100/410) || training loss 0.04409 || training accuracy 98.28% || lr 8.351141009169893e-05
# Epoch[3/10](120/410) || training loss 0.05913 || training accuracy 98.28% || lr 8.351141009169893e-05
# Epoch[3/10](140/410) || training loss 0.04358 || training accuracy 98.91% || lr 8.351141009169893e-05
# Epoch[3/10](160/410) || training loss 0.04001 || training accuracy 98.75% || lr 8.351141009169893e-05
# Epoch[3/10](180/410) || training loss 0.04464 || training accuracy 98.12% || lr 8.351141009169893e-05
# Epoch[3/10](200/410) || training loss 0.06072 || training accuracy 97.81% || lr 8.351141009169893e-05
# Epoch[3/10](220/410) || training loss 0.02445 || training accuracy 99.38% || lr 8.351141009169893e-05
# Epoch[3/10](240/410) || training loss 0.04461 || training accuracy 98.91% || lr 8.351141009169893e-05
# Epoch[3/10](260/410) || training loss 0.03443 || training accuracy 99.38% || lr 8.351141009169893e-05
# Epoch[3/10](280/410) || training loss 0.03115 || training accuracy 98.75% || lr 8.351141009169893e-05
# Epoch[3/10](300/410) || training loss 0.02288 || training accuracy 99.22% || lr 8.351141009169893e-05
# Epoch[3/10](320/410) || training loss 0.03015 || training accuracy 99.22% || lr 8.351141009169893e-05
# Epoch[3/10](340/410) || training loss 0.04451 || training accuracy 98.44% || lr 8.351141009169893e-05
# Epoch[3/10](360/410) || training loss 0.04704 || training accuracy 98.28% || lr 8.351141009169893e-05
# Epoch[3/10](380/410) || training loss 0.03294 || training accuracy 99.06% || lr 8.351141009169893e-05
# Epoch[3/10](400/410) || training loss 0.02511 || training accuracy 99.22% || lr 8.351141009169893e-05
# Calculating validation results...
# [Val] acc : 89.57%, loss:  0.3 || best acc : 91.26%, best loss: 0.27
# Accuracy By Each Label
# Age : 0, Accuracy By Age : 0.98%
# Age : 1, Accuracy By Age : 0.95%
# Age : 2, Accuracy By Age : 0.78%
# Gender : 0, Accuracy By Gender : 0.88%
# Gender : 1, Accuracy By Gender : 0.92%
# Mask : 0, Accuracy By Mask : 0.88%
# Mask : 1, Accuracy By Mask : 0.89%
# Mask : 2, Accuracy By Mask : 0.93%
#
# Epoch[4/10](20/410) || training loss 0.02754 || training accuracy 99.53% || lr 7.236067977499791e-05
# Epoch[4/10](40/410) || training loss 0.02262 || training accuracy 99.22% || lr 7.236067977499791e-05
# Epoch[4/10](60/410) || training loss 0.02654 || training accuracy 99.38% || lr 7.236067977499791e-05
# Epoch[4/10](80/410) || training loss 0.02104 || training accuracy 99.69% || lr 7.236067977499791e-05
# Epoch[4/10](100/410) || training loss 0.02994 || training accuracy 98.91% || lr 7.236067977499791e-05
# Epoch[4/10](120/410) || training loss 0.02602 || training accuracy 99.53% || lr 7.236067977499791e-05
# Epoch[4/10](140/410) || training loss 0.02222 || training accuracy 99.38% || lr 7.236067977499791e-05
# Epoch[4/10](160/410) || training loss 0.02739 || training accuracy 99.53% || lr 7.236067977499791e-05
# Epoch[4/10](180/410) || training loss 0.03787 || training accuracy 98.91% || lr 7.236067977499791e-05
# Epoch[4/10](200/410) || training loss 0.0248 || training accuracy 99.38% || lr 7.236067977499791e-05
# Epoch[4/10](220/410) || training loss 0.02029 || training accuracy 99.53% || lr 7.236067977499791e-05
# Epoch[4/10](240/410) || training loss 0.03405 || training accuracy 98.75% || lr 7.236067977499791e-05
# Epoch[4/10](260/410) || training loss 0.03607 || training accuracy 98.75% || lr 7.236067977499791e-05
# Epoch[4/10](280/410) || training loss 0.01805 || training accuracy 99.38% || lr 7.236067977499791e-05
# Epoch[4/10](300/410) || training loss 0.04006 || training accuracy 98.75% || lr 7.236067977499791e-05
# Epoch[4/10](320/410) || training loss 0.02342 || training accuracy 99.38% || lr 7.236067977499791e-05
# Epoch[4/10](340/410) || training loss 0.0281 || training accuracy 99.38% || lr 7.236067977499791e-05
# Epoch[4/10](360/410) || training loss 0.02299 || training accuracy 99.38% || lr 7.236067977499791e-05
# Epoch[4/10](380/410) || training loss 0.01576 || training accuracy 99.69% || lr 7.236067977499791e-05
# Epoch[4/10](400/410) || training loss 0.02118 || training accuracy 99.38% || lr 7.236067977499791e-05
# Calculating validation results...
# New best model for val accuracy : 92.53%! saving the best model..
# [Val] acc : 92.53%, loss: 0.17 || best acc : 92.53%, best loss: 0.17
# Accuracy By Each Label
# Age : 0, Accuracy By Age : 0.97%
# Age : 1, Accuracy By Age : 0.95%
# Age : 2, Accuracy By Age : 0.87%
# Gender : 0, Accuracy By Gender : 0.95%
# Gender : 1, Accuracy By Gender : 0.92%
# Mask : 0, Accuracy By Mask : 0.93%
# Mask : 1, Accuracy By Mask : 0.94%
# Mask : 2, Accuracy By Mask : 0.92%
#
# Epoch[5/10](20/410) || training loss 0.03382 || training accuracy 98.75% || lr 6.000000000000001e-05
# Epoch[5/10](40/410) || training loss 0.01216 || training accuracy 99.84% || lr 6.000000000000001e-05
# Epoch[5/10](60/410) || training loss 0.03701 || training accuracy 98.44% || lr 6.000000000000001e-05
# Epoch[5/10](80/410) || training loss 0.02603 || training accuracy 99.22% || lr 6.000000000000001e-05
# Epoch[5/10](100/410) || training loss 0.02201 || training accuracy 99.22% || lr 6.000000000000001e-05
# Epoch[5/10](120/410) || training loss 0.0184 || training accuracy 99.38% || lr 6.000000000000001e-05
# Epoch[5/10](140/410) || training loss 0.03129 || training accuracy 98.91% || lr 6.000000000000001e-05
# Epoch[5/10](160/410) || training loss 0.03531 || training accuracy 98.75% || lr 6.000000000000001e-05
# Epoch[5/10](180/410) || training loss 0.01142 || training accuracy 99.84% || lr 6.000000000000001e-05
# Epoch[5/10](200/410) || training loss 0.01681 || training accuracy 99.84% || lr 6.000000000000001e-05
# Epoch[5/10](220/410) || training loss 0.02612 || training accuracy 99.06% || lr 6.000000000000001e-05
# Epoch[5/10](240/410) || training loss 0.04325 || training accuracy 98.91% || lr 6.000000000000001e-05
# Epoch[5/10](260/410) || training loss 0.02031 || training accuracy 99.53% || lr 6.000000000000001e-05
# Epoch[5/10](280/410) || training loss 0.01722 || training accuracy 99.69% || lr 6.000000000000001e-05
# Epoch[5/10](300/410) || training loss 0.01594 || training accuracy 99.69% || lr 6.000000000000001e-05
# Epoch[5/10](320/410) || training loss 0.02207 || training accuracy 99.06% || lr 6.000000000000001e-05
# Epoch[5/10](340/410) || training loss 0.0129 || training accuracy 99.69% || lr 6.000000000000001e-05
# Epoch[5/10](360/410) || training loss 0.01507 || training accuracy 99.38% || lr 6.000000000000001e-05
# Epoch[5/10](380/410) || training loss 0.01016 || training accuracy 99.84% || lr 6.000000000000001e-05
# Epoch[5/10](400/410) || training loss 0.01093 || training accuracy 99.84% || lr 6.000000000000001e-05
# Calculating validation results...
# New best model for val accuracy : 94.53%! saving the best model..
# [Val] acc : 94.53%, loss: 0.18 || best acc : 94.53%, best loss: 0.17
# Accuracy By Each Label
# Age : 0, Accuracy By Age : 0.99%
# Age : 1, Accuracy By Age : 0.95%
# Age : 2, Accuracy By Age : 0.93%
# Gender : 0, Accuracy By Gender : 0.95%
# Gender : 1, Accuracy By Gender : 0.96%
# Mask : 0, Accuracy By Mask : 0.96%
# Mask : 1, Accuracy By Mask : 0.95%
# Mask : 2, Accuracy By Mask : 0.95%
#
# Epoch[6/10](20/410) || training loss 0.01574 || training accuracy 99.38% || lr 4.7639320225002116e-05
# Epoch[6/10](40/410) || training loss 0.009397 || training accuracy 99.84% || lr 4.7639320225002116e-05
# Epoch[6/10](60/410) || training loss 0.008498 || training accuracy 100.00% || lr 4.7639320225002116e-05
# Epoch[6/10](80/410) || training loss 0.02003 || training accuracy 99.53% || lr 4.7639320225002116e-05
# Epoch[6/10](100/410) || training loss 0.01251 || training accuracy 99.53% || lr 4.7639320225002116e-05
# Epoch[6/10](120/410) || training loss 0.006918 || training accuracy 100.00% || lr 4.7639320225002116e-05
# Epoch[6/10](140/410) || training loss 0.02091 || training accuracy 99.38% || lr 4.7639320225002116e-05
# Epoch[6/10](160/410) || training loss 0.01739 || training accuracy 99.53% || lr 4.7639320225002116e-05

# %%
# !python /opt/ml/level1-image-classification-level1-recsys-04/model/FaceAndCutmix/inference.py \
    --batch_size 32 \
    --model 'EfficientNet_MultiLabel' \
    --augmentation 'BaseAugmentation' \
    --model_dir './model/Face_Cutmix/' \
    --output_dir './output/Face_Cutmix'
# Out:
# Loaded pretrained weights for efficientnet-b4
# Calculating inference results..
# Inference Done!
