# %%
# !python /opt/ml/level1-image-classification-level1-recsys-04/model/FaceAndCutmix_OnlyAge/train.py \
    --epochs 10 \
    --dataset 'CutMixDataset' \
    --augmentation 'CustomAugmentation' \
    --batch_size 32 \
    --valid_batch_size 32 \
    --model 'EfficientNet_MultiLabel' \
    --lr '1e-4' \
    --lr_decay_step '10' \
    --name 'Face_Cutmix_lab_smooth_train_age' \
    --model_dir './model/' \
    --criterion 'label_smoothing'
# Out:
# Namespace(augmentation='CustomAugmentation', batch_size=32, criterion='label_smoothing', data_dir='/opt/ml/input/data/train/images', dataset='CutMixDataset', epochs=10, log_interval=20, lr=0.0001, lr_decay_step=10, model='EfficientNet_MultiLabel', model_dir='./model/', name='Face_Cutmix_lab_smooth_train_age', optimizer='Adam', resize=[380, 380], seed=42, val_ratio=0.2, valid_batch_size=32)
# @ Dataset: CutMixDataset called with num_classes=3
# Loaded pretrained weights for efficientnet-b4
# @ Model: EfficientNet_MultiLabel called with num_classes=3
# @ Loss: LabelSmoothing Loss Called with num_classes=3, smooth_value=0.1
# @ Activate RandomHorizontalFlip on 60's
# @ Activate RandomHorizontalFlip on 60's
# @ Activate RandomHorizontalFlip on 60's
# @ Activate RandomHorizontalFlip on 60's
# Epoch[0/10](20/410) || training loss 0.9977 || training accuracy 60.94% || lr 0.0001
# Epoch[0/10](40/410) || training loss 0.7374 || training accuracy 79.06% || lr 0.0001
# ...

# %%
# !python /opt/ml/level1-image-classification-level1-recsys-04/model/FaceAndCutmix_OnlyAge/inference.py \
    --batch_size 64 \
    --model 'EfficientNet_MultiLabel' \
    --augmentation 'BaseAugmentation' \
    --model_dir './model/Face_Cutmix_lab_smooth_train_all' \
    --output_dir './output/Face_Cutmix_lab_smooth_train_all'
